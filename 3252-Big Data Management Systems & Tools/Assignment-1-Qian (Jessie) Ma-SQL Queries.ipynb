# %% [markdown]
# # Assignment #1: SQL Queries

# %%
#Installing JupySQL to run SQL queries in Jupyter notebook
# %pip install jupysql --quiet
# %reload_ext sql
# %sql sqlite:///chinook.db
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
#List the tables in chinook db file
# %sqlcmd tables
# Out:
# +-----------------+
# |       Name      |
# +-----------------+
# |      albums     |
# |     artists     |
# |    customers    |
# |    employees    |
# |      genres     |
# |  invoice_items  |
# |     invoices    |
# |   media_types   |
# |  playlist_track |
# |    playlists    |
# | sqlite_sequence |
# |   sqlite_stat1  |
# |      tracks     |
# +-----------------+

# %% [markdown]
# ## Problem 1: Querying a Single Table

# %% [markdown]
# ### 1a: Write a Query that returns the following data from the Customers table:
# ### a. FirstName and Last name concatenated into a single column,
# ### b. The Company Name
# ### c. Their city
# ### d. Their state
# ### Order the resulting data by city.

# %%
#Remove row limit
# %config SqlMagic.displaylimit = 0

# %%
# %%sql
# SELECT FirstName || ' ' || LastName AS FullName,Company,City,State
# FROM customers
# ORDER BY City;
# Out:
# Running query in 'sqlite:///chinook.db'
# +-----------------------+--------------------------------------------------+---------------------+--------+
# |        FullName       |                     Company                      |         City        | State  |
# +-----------------------+--------------------------------------------------+---------------------+--------+
# | Johannes Van der Berg |                       None                       |      Amsterdam      |   VV   |
# |    Puja Srivastava    |                       None                       |      Bangalore      |  None  |
# |    Hannah Schneider   |                       None                       |        Berlin       |  None  |
# |    Niklas Schröder    |                       None                       |        Berlin       |  None  |
# |      Wyatt Girard     |                       None                       |       Bordeaux      |  None  |
# ...

# %% [markdown]
# ### 1b: Modify your query to only return customers from Canada or the United States.

# %%
# %%sql
# SELECT FirstName || ' ' || LastName AS FullName,Company,City,State
# FROM customers
# WHERE Country = 'Canada' OR Country = 'USA'
# ORDER BY City;
# Out:
# Running query in 'sqlite:///chinook.db'
# +--------------------+-----------------------+----------------+-------+
# |      FullName      |        Company        |      City      | State |
# +--------------------+-----------------------+----------------+-------+
# |    John Gordon     |          None         |     Boston     |   MA  |
# |   Frank Ralston    |          None         |    Chicago     |   IL  |
# |     Tim Goyer      |       Apple Inc.      |   Cupertino    |   CA  |
# |    Mark Philips    |         Telus         |    Edmonton    |   AB  |
# | Richard Cunningham |          None         |   Fort Worth   |   TX  |
# |    Martha Silk     |          None         |    Halifax     |   NS  |
# |   Victor Stevens   |          None         |    Madison     |   WI  |
# | François Tremblay  |          None         |    Montréal    |   QC  |
# |    Frank Harris    |      Google Inc.      | Mountain View  |   CA  |
# ...

# %% [markdown]
# ### 1c: Modify your query to only return customers in Canada or the United States whose last name starts with the letter M.

# %%
# %%sql
# SELECT FirstName || ' ' || LastName AS FullName,Company,City,State
# FROM customers
# WHERE (Country = 'Canada' OR Country = 'USA') AND LastName LIKE 'M%'
# ORDER BY City;
# Out:
# Running query in 'sqlite:///chinook.db'
# +----------------+---------+---------------+-------+
# |    FullName    | Company |      City     | State |
# +----------------+---------+---------------+-------+
# |   Dan Miller   |   None  | Mountain View |   CA  |
# | Aaron Mitchell |   None  |    Winnipeg   |   MB  |
# +----------------+---------+---------------+-------+

# %% [markdown]
# ## Problem 2: Joining tables

# %% [markdown]
# ### 2a: Write a query which returns the following information from the Artist, Albums and Tracks tables:
# ### a. Artist Name
# ### b. Album Title
# ### c. Track Names
# ### Order the results by Artists

# %%
# %%sql
# SELECT artists.Name AS ArtistName, albums.Title AS AlbumTitle, tracks.Name AS TrackName
# FROM artists
# INNER JOIN albums ON artists.ArtistId=albums.ArtistId
# INNER JOIN tracks ON albums.AlbumId=tracks.AlbumId
# ORDER BY artists.Name;
# Out:
# Running query in 'sqlite:///chinook.db'
# +---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------+
# |                                       ArtistName                                      |                                            AlbumTitle                                           |                                                          TrackName                                                          |
# +---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------+
# ...

# %% [markdown]
# ### 2b: Modify the previous query so it only returns tracks that have the word “dancing” somewhere in the track name.

# %%
# %%sql
# SELECT artists.Name AS ArtistName, albums.Title AS AlbumTitle, tracks.Name AS TrackName
# FROM artists
# INNER JOIN albums ON artists.ArtistId=albums.ArtistId
# INNER JOIN tracks ON albums.AlbumId=tracks.AlbumId
# WHERE tracks.Name LIKE '%dancing%'
# ORDER BY artists.Name;
# Out:
# Running query in 'sqlite:///chinook.db'
# +--------------+--------------------+-----------------------+
# |  ArtistName  |     AlbumTitle     |       TrackName       |
# +--------------+--------------------+-----------------------+
# | Led Zeppelin | Houses Of The Holy |      Dancing Days     |
# |      U2      | B-Sides 1980-1990  |    Dancing Barefoot   |
# |  Van Halen   |     Diver Down     | Dancing In The Street |
# +--------------+--------------------+-----------------------+

# %% [markdown]
# ### 2c: You have been asked to create a org chart for the company. Create a query that returns two columns one with the employee’s first and last name and the second with their managers first and last name.
# ### Example:
# ### Employee Manager
# ### Nancy Edwards | Andrew Adams

# %%
# %%sql
# SELECT e.FirstName || ' ' || e.LastName AS Employee,m.FirstName || ' ' || m.LastName AS Manager
# FROM employees e
# JOIN employees m ON e.reportsto = m.employeeid
# WHERE e.reportsto IS NOT NULL;
# Out:
# Running query in 'sqlite:///chinook.db'
# +------------------+------------------+
# |     Employee     |     Manager      |
# +------------------+------------------+
# |  Nancy Edwards   |   Andrew Adams   |
# |   Jane Peacock   |  Nancy Edwards   |
# |  Margaret Park   |  Nancy Edwards   |
# |  Steve Johnson   |  Nancy Edwards   |
# | Michael Mitchell |   Andrew Adams   |
# |   Robert King    | Michael Mitchell |
# |  Laura Callahan  | Michael Mitchell |
# +------------------+------------------+

# %% [markdown]
# ### 2d: When you review the list you notice that the General Manager, Andrew Adams, is not included on the list. Modify your query from 2c: to include Andrew so the record looks as follows: “Andrew Adams reports to himself”

# %%
# %%sql
# SELECT e.FirstName || ' ' || e.LastName AS Employee,
#     (CASE
#         WHEN e.ReportsTo IS NULL THEN (e.FirstName || ' ' || e.LastName) || ' ' || 'reports to himself'
#         ELSE m.FirstName || ' ' || m.LastName
#     END) AS Manager
# FROM employees e
# LEFT JOIN employees m ON e.reportsto = m.employeeid;
# Out:
# Running query in 'sqlite:///chinook.db'
# +------------------+---------------------------------+
# |     Employee     |             Manager             |
# +------------------+---------------------------------+
# |   Andrew Adams   | Andrew Adams reports to himself |
# |  Nancy Edwards   |           Andrew Adams          |
# |   Jane Peacock   |          Nancy Edwards          |
# |  Margaret Park   |          Nancy Edwards          |
# |  Steve Johnson   |          Nancy Edwards          |
# | Michael Mitchell |           Andrew Adams          |
# |   Robert King    |         Michael Mitchell        |
# |  Laura Callahan  |         Michael Mitchell        |
# +------------------+---------------------------------+

# %% [markdown]
# ## Problem 3: Aggregation

# %% [markdown]
# ### 3a: Create a report that that Joins the Albums to Tracks table and returns the title of each album and the number of tracks it contains.

# %%
# %%sql
# SELECT albums.Title AS AlbumTitle, COUNT(tracks.TrackID) AS NumberofTracks
# FROM albums
# INNER JOIN tracks ON albums.AlbumId=tracks.AlbumId
# GROUP BY albums.AlbumID
# ORDER BY albums.Title;
# Out:
# Running query in 'sqlite:///chinook.db'
# +-------------------------------------------------------------------------------------------------+----------------+
# |                                            AlbumTitle                                           | NumberofTracks |
# +-------------------------------------------------------------------------------------------------+----------------+
# |                                      ...And Justice For All                                     |       9        |
# |             20th Century Masters - The Millennium Collection: The Best of Scorpions             |       12       |
# |                                  A Copland Celebration, Vol. I                                  |       1        |
# |                                    A Matter of Life and Death                                   |       11       |
# |                                         A Real Dead One                                         |       12       |
# ...

# %% [markdown]
# ### 3b: Modify your query from 3a so that the report only shows albums that have more than ten tracks.

# %%
# %%sql
# SELECT albums.Title AS AlbumTitle, COUNT(tracks.TrackID) AS NumberofTracks
# FROM albums
# INNER JOIN tracks ON albums.AlbumId=tracks.AlbumId
# GROUP BY albums.AlbumID
# HAVING NumberofTracks>10
# ORDER BY albums.Title;
# Out:
# Running query in 'sqlite:///chinook.db'
# +------------------------------------------------------------------------------+----------------+
# |                                  AlbumTitle                                  | NumberofTracks |
# +------------------------------------------------------------------------------+----------------+
# |   20th Century Masters - The Millennium Collection: The Best of Scorpions    |       12       |
# |                          A Matter of Life and Death                          |       11       |
# |                               A Real Dead One                                |       12       |
# |                               A Real Live One                                |       11       |
# |                  A TempestadeTempestade Ou O Livro Dos Dias                  |       15       |
# |                                   A-Sides                                    |       17       |
# ...
